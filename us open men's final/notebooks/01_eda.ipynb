# %%
# EDA
Quick sanity checks: class balance, correlations, feature drift.

# %%
import pandas as pd
X = pd.read_parquet('data/processed/X_train.parquet')
y = pd.read_parquet('data/processed/y_train.parquet')['y']
print('Rows:', len(X))
print('Class balance:', y.mean())
